# %% [markdown]
# <a href="https://colab.research.google.com/github/TiaErikaDev/ADA-Tecnicas_Programacao/blob/main/%5BADA%5D_Analise_Exploratoria_Dados_Churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Importando as bibliotecas**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Fazendo a leitura do arquivo**

# %%
df_churn = pd.read_csv('/content/drive/MyDrive/churn.csv', index_col='RowNumber')
df_churn
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %% [markdown]
# ### **Deletando colunas desnecessárias à análise**

# %%
arr_delete = ['CustomerId', 'Surname']

df_churn.drop(arr_delete, axis=1, inplace = True)
df_churn
# Out:
#            CreditScore Geography  Gender  Age  Tenure    Balance  \
# RowNumber
# 1                  619    France  Female   42       2       0.00
# 2                  608     Spain  Female   41       1   83807.86
# 3                  502    France  Female   42       8  159660.80
# 4                  699    France  Female   39       1       0.00
# 5                  850     Spain  Female   43       2  125510.82
# ...                ...       ...     ...  ...     ...        ...
# 9996               771    France    Male   39       5       0.00
# 9997               516    France    Male   35      10   57369.61
# 9998               709    France  Female   36       7       0.00
# 9999               772   Germany    Male   42       3   75075.31
# 10000              792    France  Female   28       4  130142.79
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# RowNumber
# 1                      1          1               1        101348.88       1
# ...

# %% [markdown]
# ### **Separando as colunas quantitativas das qualitativas**

# %%
qualitativa = ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember', 'Exited']
quantitativa = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary', 'Exited']

df_churn_quali = df_churn[qualitativa]
df_churn_quanti = df_churn[quantitativa]
